# %% [markdown]
# # RNN Model with crf

# %%
import rnn_dataset
import rnn_classifier
from crf import CRF
import torch
from data_utils import Vocabulary
from torch.utils.data import Dataset, DataLoader, random_split
from collections import Counter
import itertools
import torch.nn as nn
from tqdm import tqdm
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
from torch.nn.utils.rnn import pad_sequence
imort pyconll

# %%
def readfile(filename, update=False, toks_vocab=Vocabulary([ "<unk>", "<bos>", "<eos>", "<pad>"]), tags_vocab=Vocabulary([ "<unk>", "<bos>", "<eos>", "<pad>"]), deprel_vocab=Vocabulary([ "<unk>", "<bos>", "<eos>", "<pad>"])):
    """
    function to read the corpus at one pass
    signature for train corpus : X_toks, Y_tags = readfile("corpus/train.conllu", update=True)
    signature for test corpus/ dev corpus:  X_test, Y_test = readfile("corpus/train.conllu", update=True, vocabtoks_train, vocabtags_train)
    """

    istream = open(filename, encoding="utf-8")
    corpus = []
    toks, mwes, deprels = [], [], []
    for line in istream:
        line = line.strip()
        if line and line[0] != "#":
            try:
                tokidx, token, lemma, upos, pos, features, headidx, deprel, extended, _ = line.split()
            except ValueError:
                print(line)
                print(corpus[-1])
            #print(upos)
            """
            if tokidx == "1":
                # beginning of sentence, add false toks
                toks.append("<bos>")
                mwes.append("<bos>")
                deprels.append("<bos>")
            """

            # extract tagging information
            # extract simple mwe tags
            extr_mwe = lambda x: "I" if features.startswith("component") else "B"

            mwe = extr_mwe(features)+"_"+upos
            toks.append(token)
            mwes.append(mwe)
            deprels.append(deprel)

            if update:
                toks_vocab.update(token)
                tags_vocab.update(mwe)
                deprel_vocab.update(deprel)

        elif toks:
            # end of sentence, add  false tokens
            #corpus.append({"tok": toks+ ["<eos>"], "mwe":mwes+["<eos>"], "deprel": deprels+ ["<eos>"] })
            corpus.append({"tok": toks , "mwe": mwes , "deprel": deprels })
            toks, mwes, deprels = [], [], []

    istream.close()
    # return the encoded data in list of list, the nested list represents the sentences
    return corpus, toks_vocab, tags_vocab, deprel_vocab

# %%
corpus, toks_vocab, tags_vocab, deprel_vocab = readfile("sequoia/sequoia.deep_and_surf.conll")

# %%
len(corpus)
# Out:
# 3099

# %%
corpus, toks_vocab, tags_vocab, deprel_vocab = readfile("corpus/train.conllu")

# %%
len(corpus)
# Out:
# 11617

# %%
#define the hyperparameters
batch_size    = 16
window_size   =  6#left context and right context
lr            = 1e-3
device        = "cpu"
epochs        = 20
emb_size      = 64
hidden_size   = 64
nb_layers     = 2
drop_out      = 0.1

# %%
trainset     = rnn_dataset.MweRnnDataset("corpus/train.conllu",  isTrain = True)
testset      = rnn_dataset.MweRnnDataset("corpus/test.conllu")
# Out:
# token Vocab size 35693
# token Vocab size 35693

# %%
for x, d, tag in testset.get_loader(shuffle = True):
    print(list(trainset.tags_vocab.rev_lookup(int(t)) for t in tag.squeeze(0)))
    break
# Out:
# ['B_CL', 'B_V', 'B_V', 'B_N', 'B_ADV', 'B__', 'I_P', 'B_D', 'B_N', 'B_V', 'B_P', 'I_N', 'I_P', 'B_V', 'B_D', 'B_N', 'B_A', 'B_P', 'B_D', 'B_N', 'B_P', 'B_V', 'B_D', 'B_N', 'B_PONCT', '<pad>']

# %%
model = rnn_classifier.MweRNN(
    name         = "rnn",
    toks_vocab   = trainset.toks_vocab,
    tags_vocab   = trainset.tags_vocab, 
    deprel_vocab = trainset.deprel_vocab,
    emb_size     = emb_size, 
    hidden_size  = hidden_size, 
    drop_out     = 0.)

# %%
model.train_model(trainset,testset, epochs= epochs, lr=lr, batch_size = batch_size, split_train=0.8)
# Out:
# 100%|█████████████████████████████████████████| 581/581 [00:32<00:00, 17.70it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 60.76it/s]
# Epoch 0 | Mean train loss  46.4963 |  Mean dev loss  29.1421
# 100%|█████████████████████████████████████████| 581/581 [00:31<00:00, 18.17it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 50.56it/s]
# Epoch 1 | Mean train loss  24.7811 |  Mean dev loss  21.4905
# 100%|█████████████████████████████████████████| 581/581 [00:33<00:00, 17.60it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 55.16it/s]
# Epoch 2 | Mean train loss  18.6540 |  Mean dev loss  17.4223
# 100%|█████████████████████████████████████████| 581/581 [00:31<00:00, 18.20it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 59.49it/s]
# Epoch 3 | Mean train loss  15.2325 |  Mean dev loss  13.6854
# 100%|█████████████████████████████████████████| 581/581 [00:30<00:00, 18.77it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 58.49it/s]
# Epoch 4 | Mean train loss  12.5433 |  Mean dev loss  11.9401
# 100%|█████████████████████████████████████████| 581/581 [00:31<00:00, 18.47it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 54.04it/s]
# Epoch 5 | Mean train loss  10.7902 |  Mean dev loss  9.6202
# 100%|█████████████████████████████████████████| 581/581 [00:32<00:00, 18.03it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 51.01it/s]
# Epoch 6 | Mean train loss  9.1894 |  Mean dev loss  8.6488
# 100%|█████████████████████████████████████████| 581/581 [00:35<00:00, 16.15it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 57.88it/s]
# Epoch 7 | Mean train loss  7.9519 |  Mean dev loss  7.7272
# 100%|█████████████████████████████████████████| 581/581 [00:40<00:00, 14.30it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 52.66it/s]
# Epoch 8 | Mean train loss  6.9455 |  Mean dev loss  6.6765
# 100%|█████████████████████████████████████████| 581/581 [00:31<00:00, 18.32it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 59.61it/s]
# Epoch 9 | Mean train loss  6.0916 |  Mean dev loss  5.9257
# 100%|█████████████████████████████████████████| 581/581 [00:32<00:00, 18.01it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 55.40it/s]
# Epoch 10 | Mean train loss  5.4091 |  Mean dev loss  5.1306
# 100%|█████████████████████████████████████████| 581/581 [00:35<00:00, 16.58it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 54.23it/s]
# Epoch 11 | Mean train loss  4.7402 |  Mean dev loss  4.6164
# 100%|█████████████████████████████████████████| 581/581 [00:34<00:00, 17.07it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 57.99it/s]
# Epoch 12 | Mean train loss  4.1751 |  Mean dev loss  4.2324
# 100%|█████████████████████████████████████████| 581/581 [00:33<00:00, 17.29it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 57.86it/s]
# Epoch 13 | Mean train loss  3.7260 |  Mean dev loss  3.6971
# 100%|█████████████████████████████████████████| 581/581 [00:30<00:00, 19.08it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 60.29it/s]
# Epoch 14 | Mean train loss  3.2615 |  Mean dev loss  3.4191
# 100%|█████████████████████████████████████████| 581/581 [00:31<00:00, 18.56it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 56.19it/s]
# Epoch 15 | Mean train loss  2.9654 |  Mean dev loss  2.8791
# 100%|█████████████████████████████████████████| 581/581 [00:34<00:00, 16.64it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 54.99it/s]
# Epoch 16 | Mean train loss  2.6388 |  Mean dev loss  2.6459
# 100%|█████████████████████████████████████████| 581/581 [00:33<00:00, 17.60it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 51.53it/s]
# Epoch 17 | Mean train loss  2.3498 |  Mean dev loss  2.3470
# 100%|█████████████████████████████████████████| 581/581 [00:31<00:00, 18.37it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 60.98it/s]
# Epoch 18 | Mean train loss  2.1079 |  Mean dev loss  2.1175
# 100%|█████████████████████████████████████████| 581/581 [00:31<00:00, 18.63it/s]
# 100%|█████████████████████████████████████████| 146/146 [00:02<00:00, 62.43it/s]
# Epoch 19 | Mean train loss  1.9092 |  Mean dev loss  1.8602
#   0%|                                                   | 0/105 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model.train_model(trainset,testset, epochs= epochs, lr=lr, batch_size = batch_size, split_train=0.8)
#
# File ~/Projects/MWE/rnn_classifier.py:105, in train_model(self, train_data, test_data, epochs, lr, batch_size, device, split_train)
#     103 TP, FP, FN, average_precision, average_recall, average_f1_score, weighted_f1_score, weighted_recall, weighted_precision = self.evaluate(test_loader)
#     104 print("AVR: Precision %.4f | Recall  %.4f |  F-score  %.4f " % (average_precision, average_recall, average_f1_score))
# --> 105 print("Weighted: Precision %.4f | Recall  %.4f |  F-score  %.4f " % (weighted_f1_score, weighted_recall, weighted_precision))
#
# File ~/Projects/MWE/rnn_classifier.py:157, in evaluate(self, test_loader)
#     155                 TP[tag] += (path == tag) & (gold == tag).sum()
#     156                 FP[tag] += (path == tag) & (gold != tag).sum()
# --> 157                 FN[tag] += (path != tag) & (gold == tag).sum()
#     158                 class_counts[tag] += (gold == tag).sum()
#     161 # Calculate precision, recall, and F1 score for each tag
#
# AttributeError: 'bool' object has no attribute 'sum'

# %%
TP, FP, FN, average_precision, average_recall, average_f1_score, weighted_f1_score, weighted_recall, weighted_precision = model.evaluate()

# %%
num_tags = len(model.tags_vocab)
# print(num_tags)
TP = torch.zeros(num_tags)
FP = torch.zeros(num_tags)
FN = torch.zeros(num_tags)
class_counts = torch.zeros(num_tags)
with torch.no_grad():
            
    for X_toks, deprel, Y_golds in tqdm(testset.get_loader(batch_size = 500)):
    # Forward pass
        logprobs, masks = model.forward(X_toks)
        best_score, best_paths = model.crf(logprobs, masks) #viterbi
        #best_paths = pad_sequence(best_paths, padding_value= testset.tags_vocab["<pad>"]).T
        #print(best_paths.shape)
        # Mask out the padding positions
        #print(best_paths)
        
        for path, gold, x in zip(best_paths, Y_golds, X_toks):
            print(f"token {list(model.toks_vocab.rev_lookup(int(i)) for i in x if i!= 1)}")
            print(f"prediction {list(model.tags_vocab.rev_lookup(i) for i in path)}")
            print(f"gold {list(model.tags_vocab.rev_lookup(int(i)) for i in gold if i!= 1)}")
        print(Y_golds.shape)
        # Update confusion matrix
        for tag in range(num_tags):
            TP[tag] += ((best_paths == tag) & (Y_golds == tag)).sum()
            FP[tag] += ((best_paths == tag) & (Y_golds != tag)).sum()
            FN[tag] += ((best_paths != tag) & (Y_golds == tag)).sum()
            class_counts[tag] += (Y_golds == tag).sum()
# Out:
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
# token ['Gutenberg']
# prediction ['B_ADV']
# gold ['B_N']
# token ['Cette', 'exposition', 'nous', 'apprend', 'que', 'dès', 'le', 'XIIe', 'siècle', ',', 'à', '<unk>', ',', 'entre', 'autres', 'sites', ',', 'une', 'industrie', '<unk>', 'existait', '.']
# prediction ['B_DET', 'B_NOUN', 'B_PRON', 'B_VERB', 'B_ADV', 'B_ADP', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_PROPN', 'B_PUNCT', 'B_ADP', 'B_ADJ', 'B_NOUN', 'B_PUNCT', 'B_DET', 'B_NOUN', 'B_AUX', 'B_VERB', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_CL', 'B_V', 'B_C', 'B_P', 'B_D', 'B_A', 'B_N', 'B_PONCT', 'B_P', 'B_N', 'B_PONCT', 'B_P', 'B_A', 'B_N', 'B_PONCT', 'B_D', 'B_N', 'B_A', 'B_V', 'B_PONCT']
# token ['à', 'peu', 'près', 'au', 'à', 'le', 'même', 'moment', 'que', 'Gutenberg', '<unk>', "l'", 'imprimerie', ',', '<unk>', '<unk>', 'créait', 'en', '1450', 'la', 'première', 'forge', 'à', '<unk>', ',', 'à', "l'", 'actuel', 'emplacement', 'du', 'de', 'le', '<unk>', '.']
# prediction ['B_ADP', 'B_ADV', 'B_ADV', 'B__', 'B_ADP', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_SCONJ', 'B_PROPN', 'B_VERB', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_PROPN', 'B_PROPN', 'B_VERB', 'B_ADP', 'B_NUM', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_ADJ', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PUNCT']
# gold ['B_P', 'I_ADV', 'I_ADV', 'B__', 'B_P', 'B_D', 'B_A', 'B_N', 'B_C', 'B_N', 'B_V', 'B_D', 'B_N', 'B_PONCT', 'B_N', 'B_N', 'B_V', 'B_P', 'B_N', 'B_D', 'B_A', 'B_N', 'B_P', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_A', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['Ensuite', ',', 'fut', 'installée', 'une', 'autre', 'forge', 'à', 'la', '<unk>', ',', 'à', "l'", 'emplacement', "aujourd'", 'hui', 'de', '<unk>', '.']
# prediction ['B_ADV', 'B_PUNCT', 'B_AUX', 'B_VERB', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_PUNCT']
# gold ['B_ADV', 'B_PONCT', 'B_V', 'B_V', 'B_D', 'B_A', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_N', 'B_P', 'I_N', 'B_P', 'B_N', 'B_PONCT']
# token ['En', '1953', ',', 'les', 'hauts', '<unk>', 'et', 'fonderies', 'de', '<unk>', 'virent', 'le', 'jour', ',', 'puis', 'Jean', '<unk>', ',', 'maire', '<unk>', 'de', '<unk>', ',', 'autorisé', 'par', 'lettres', '<unk>', "d'", 'Henri', 'IV', ',', 'installa', 'à', '<unk>', '-', 'qui', 'signifiait', 'val', 'ou', 'vallée', 'de', 'la', 'Marne', 'ou', 'bien', 'en', 'aval', 'de', 'la', 'Marne', '-', ',', 'une', 'forge', 'qui', 'connut', 'son', '<unk>', 'au', 'à', 'le', 'XIXe', 'siècle', '.']
# prediction ['B_ADP', 'B_NUM', 'B_PUNCT', 'B_DET', 'B_ADJ', 'B_PROPN', 'B_CONJ', 'B_NUM', 'B_ADP', 'B_PROPN', 'B_VERB', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_ADV', 'B_PROPN', 'B_PROPN', 'B_PUNCT', 'B_NOUN', 'B_VERB', 'B_ADP', 'B_PROPN', 'B_PUNCT', 'B_VERB', 'B_ADP', 'B_NOUN', 'B_PROPN', 'B_ADP', 'B_PROPN', 'B_NUM', 'B_PUNCT', 'B_PROPN', 'B_ADP', 'B_PROPN', 'B_PUNCT', 'B_PRON', 'B_VERB', 'B_ADJ', 'B_CONJ', 'B_NOUN', 'B_ADP', 'B_DET', 'B_PROPN', 'B_CONJ', 'B_ADV', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PUNCT', 'B_PUNCT', 'B_DET', 'B_NOUN', 'B_PRON', 'B_VERB', 'B_DET', 'B_PROPN', 'B__', 'B_ADP', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_PUNCT']
# gold ['B_P', 'B_N', 'B_PONCT', 'B_D', 'B_A', 'B_N', 'B_C', 'B_N', 'B_P', 'B_N', 'B_V', 'B_D', 'B_N', 'B_PONCT', 'B_C', 'B_N', 'B_N', 'B_PONCT', 'B_N', 'B_N', 'B_P', 'B_N', 'B_PONCT', 'B_V', 'B_P', 'B_N', 'B_A', 'B_P', 'B_N', 'B_A', 'B_PONCT', 'B_V', 'B_P', 'B_N', 'B_PONCT', 'B_PRO', 'B_V', 'B_N', 'B_C', 'B_N', 'B_P', 'B_D', 'B_N', 'B_C', 'I_ADV', 'B_P', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_PONCT', 'B_D', 'B_N', 'B_PRO', 'B_V', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_A', 'B_N', 'B_PONCT']
# token ['Tout', 'au', 'à', 'le', 'long', 'des', 'de', 'les', 'années', ',', 'de', 'nouveaux', 'sites', 'furent', 'créés', ',', 'notamment', 'à', '<unk>', ',', 'puis', 'plus', 'tard', 'à', '<unk>', '.']
# prediction ['B_ADV', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_ADJ', 'B_NOUN', 'B_AUX', 'B_VERB', 'B_PUNCT', 'B_ADV', 'B_ADP', 'B_PROPN', 'B_PUNCT', 'B_ADV', 'B_ADV', 'B_ADV', 'B_ADP', 'B_PROPN', 'B_PUNCT']
# gold ['B_ADV', 'B__', 'I_P', 'B_D', 'I_N', 'B__', 'I_P', 'B_D', 'B_N', 'B_PONCT', 'B_D', 'B_A', 'B_N', 'B_V', 'B_V', 'B_PONCT', 'B_ADV', 'B_P', 'B_N', 'B_PONCT', 'B_C', 'B_ADV', 'I_ADV', 'B_P', 'B_N', 'B_PONCT']
# token ['<unk>', 'de', 'la', 'sécurité']
# prediction ['B_V', 'B_P', 'B_D', 'B_N']
# gold ['B_N', 'B_P', 'B_D', 'B_N']
# token ['Le', 'maire', 'a', 'invité', 'les', 'membres', 'du', 'de', 'le', 'conseil', 'à', 'élaborer', 'le', 'programme', "d'", 'amélioration', 'de', 'la', 'voirie', 'communale', 'et', 'de', 'la', 'sécurité', 'routière', 'pour', "l'", 'année', '1999', '.']
# prediction ['B_DET', 'B_NOUN', 'B_AUX', 'B_VERB', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_CONJ', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_ADP', 'B_DET', 'B_NOUN', 'B_NUM', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_V', 'B_V', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_P', 'B_V', 'B_D', 'B_N', 'B_P', 'B_N', 'B_P', 'B_D', 'B_N', 'B_A', 'B_C', 'B_P', 'B_D', 'B_N', 'B_A', 'B_P', 'B_D', 'B_N', 'B_N', 'B_PONCT']
# token ['Il', 'a', 'rappelé', 'que', 'plusieurs', 'automobilistes', 'ont', 'quitté', 'la', 'chaussée', 'à', "l'", 'intersection', 'de', 'la', '<unk>', 'et', 'du', 'de', 'le', 'chemin', 'rural', 'de', 'la', 'Vaux', 'des', 'de', 'les', '<unk>', 'et', "qu'", 'il', 'convient', 'de', 'modifier', 'le', 'régime', 'de', 'priorité', 'à', 'cet', 'endroit', '.']
# prediction ['B_PRON', 'B_AUX', 'B_VERB', 'B_SCONJ', 'B_DET', 'B_NOUN', 'B_AUX', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_PROPN', 'B_CONJ', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_ADP', 'B_DET', 'B_PROPN', 'B__', 'B_ADP', 'B_DET', 'B_PROPN', 'B_CONJ', 'B_PRON', 'B_PRON', 'B_VERB', 'B_ADP', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_CL', 'B_V', 'B_V', 'B_C', 'B_D', 'B_N', 'B_V', 'B_V', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_C', 'B__', 'B_P', 'B_D', 'B_N', 'B_A', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_C', 'B_C', 'B_CL', 'B_V', 'B_P', 'B_V', 'B_D', 'B_N', 'B_P', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['La', 'pose', "d'", 'un', 'panneau', 'stop', 'paraît', 'être', 'la', 'formule', 'la', 'mieux', 'adaptée', 'pour', 'assurer', 'la', 'sécurité', 'des', 'de', 'les', 'usagers', '.']
# prediction ['B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PROPN', 'B_PROPN', 'B_VERB', 'B_DET', 'B_NOUN', 'B_DET', 'B_ADV', 'B_A', 'B_P', 'B_V', 'B_D', 'B_N', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_N', 'B_V', 'B_V', 'B_D', 'B_N', 'B_D', 'B_ADV', 'B_A', 'B_P', 'B_V', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['En', '<unk>', ',', "l'", 'assemblée', 'a', 'accepté', 'la', 'proposition', 'du', 'de', 'le', 'maire', 'et', "l'", 'a', 'chargé', 'de', 'faire', 'établir', 'par', 'les', 'services', 'de', 'la', 'DDE', 'un', 'dossier', 'de', 'demande', 'de', 'subvention', 'dans', 'le', 'cadre', 'de', 'la', 'répartition', 'des', 'de', 'les', 'amendes', 'de', 'police', '1999', '.']
# prediction ['B_ADP', 'B_PROPN', 'B_PUNCT', 'B_DET', 'B_NOUN', 'B_AUX', 'B_VERB', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_CONJ', 'B_PRON', 'B_AUX', 'B_VERB', 'B_ADP', 'B_VERB', 'B_VERB', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_PROPN', 'B_D', 'B_N', 'B_P', 'B_N', 'B_P', 'B_N', 'B_P', 'B_D', 'I_N', 'I_P', 'B_D', 'B_N', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_ADJ', 'B_PUNCT']
# gold ['B_P', 'B_V', 'B_PONCT', 'B_D', 'B_N', 'B_V', 'B_V', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_C', 'B_CL', 'B_V', 'B_V', 'B_P', 'B_V', 'B_V', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_D', 'B_N', 'B_P', 'B_N', 'B_P', 'B_N', 'B_P', 'I_D', 'I_N', 'I_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_N', 'B_PONCT']
# token ['Espoir']
# prediction ['B_ADP']
# gold ['B_N']
# token ['La', 'remise', 'du', 'de', 'le', '<unk>', 'abrite', 'depuis', 'quelques', 'jours', 'une', 'exposition', 'qui', 'a', 'été', 'inaugurée', 'par', 'Roger', '<unk>', ',', 'président', 'de', "l'", 'Association', "d'", 'insertion', 'des', 'de', 'les', 'pays', 'de', 'la', '<unk>', 'et', 'du', 'de', 'le', '<unk>', ',', 'en', 'présence', 'de', 'nombreux', 'élus', 'du', 'de', 'le', 'canton', '.']
# prediction ['B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PROPN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_DET', 'B_NOUN', 'B_PRON', 'B_AUX', 'B_AUX', 'B_VERB', 'B_ADP', 'B_PROPN', 'B_PROPN', 'B_PUNCT', 'B_NOUN', 'B_ADP', 'B_DET', 'B_PROPN', 'B_ADP', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_PROPN', 'B_CONJ', 'B__', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PUNCT', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_ADJ', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_V', 'B_P', 'B_D', 'B_N', 'B_D', 'B_N', 'B_PRO', 'B_V', 'B_V', 'B_V', 'B_P', 'B_N', 'B_N', 'B_PONCT', 'B_N', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_C', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_P', 'I_N', 'I_P', 'B_A', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ["L'", 'association', 'a', 'changé', 'les', 'décors', 'et', 'avec', "l'", 'aide', 'de', 'plusieurs', 'bénévoles', ',', 'établi', 'différents', 'tableaux', 'sur', 'le', 'thème', 'de', '"', 'Cinq', 'siècles', "d'", 'activité', 'économique', 'de', 'la', 'région', "d'", '<unk>', '"', '.']
# prediction ['B_DET', 'B_NOUN', 'B_AUX', 'B_VERB', 'B_DET', 'B_NOUN', 'B_CONJ', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_VERB', 'B_ADJ', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_PUNCT', 'B_NUM', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_ADJ', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_PUNCT', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_V', 'B_V', 'B_D', 'B_N', 'B_C', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_V', 'B_A', 'B_N', 'B_P', 'B_D', 'B_N', 'B_P', 'B_PONCT', 'B_D', 'B_N', 'B_P', 'B_N', 'B_A', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT', 'B_PONCT']
# token ['Pourquoi', 'ce', 'thème', '?']
# prediction ['B_ADV', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_ADV', 'B_D', 'B_N', 'B_PONCT']
# token ['"', 'Tout', 'simplement', '"', ',', 'a', 'précisé', 'Roger', '<unk>', ',', '"', 'parce', 'que', "l'", 'histoire', 'du', 'de', 'le', 'travail', 'industriel', 'est', ',', 'ici', ',', 'une', 'longue', 'et', 'vieille', 'histoire', '.']
# prediction ['B_PONCT', 'B_A', 'B_ADV', 'B_PUNCT', 'B_PUNCT', 'B_AUX', 'B_VERB', 'B_PROPN', 'B_PROPN', 'B_PUNCT', 'B_PUNCT', 'B_ADV', 'B_SCONJ', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_VERB', 'B_PUNCT', 'B_ADV', 'B_PUNCT', 'B_DET', 'B_ADJ', 'B_CONJ', 'B_ADJ', 'B_NOUN', 'B_PUNCT']
# gold ['B_PONCT', 'B_ADV', 'B_ADV', 'B_PONCT', 'B_PONCT', 'B_V', 'B_V', 'B_N', 'B_N', 'B_PONCT', 'B_PONCT', 'B_C', 'I_C', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_A', 'B_V', 'B_PONCT', 'B_ADV', 'B_PONCT', 'B_D', 'B_A', 'B_C', 'B_A', 'B_N', 'B_PONCT']
# token ['La', 'présence', "d'", 'une', 'abondante', 'forêt', ',', 'fournissant', "l'", 'indispensable', 'combustible', ',', 'liée', 'à', "l'", 'existence', 'du', 'de', 'le', 'minerai', 'de', 'fer', '<unk>', 'à', 'ciel', 'ouvert', ',', 'a', '<unk>', 'les', 'hommes', 'à', 'créer', '"', '.']
# prediction ['B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_PUNCT', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_PUNCT', 'B_VERB', 'B_ADP', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_VERB', 'B_ADP', 'B_NOUN', 'B_ADJ', 'B_PUNCT', 'B_AUX', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_PUNCT', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_P', 'B_D', 'B_A', 'B_N', 'B_PONCT', 'B_V', 'B_D', 'B_A', 'B_N', 'B_PONCT', 'B_V', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_A', 'B_P', 'B_N', 'B_A', 'B_PONCT', 'B_V', 'B_V', 'B_D', 'B_N', 'B_P', 'B_V', 'B_PONCT', 'B_PONCT']
# token ["C'", 'est', 'donc', 'toute', 'la', 'vie', 'industrielle', 'du', 'de', 'le', 'bassin', 'de', '<unk>', ',', 'sans', 'oublier', 'les', '<unk>', 'de', '<unk>', ',', 'les', 'carrières', 'de', '<unk>', ',', 'que', 'les', 'visiteurs', 'du', 'de', 'le', '<unk>', 'pourront', 'découvrir', '.']
# prediction ['B_PRON', 'B_VERB', 'B_ADV', 'B_DET', 'B_DET', 'B_NOUN', 'B_ADJ', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_PUNCT', 'B_ADP', 'B_NOUN', 'B_DET', 'B_PROPN', 'B_ADP', 'B_PROPN', 'B_PUNCT', 'B_DET', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_PUNCT', 'B_SCONJ', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_PROPN', 'B_AUX', 'B_VERB', 'B_PUNCT']
# gold ['B_CL', 'B_V', 'B_ADV', 'B_A', 'B_D', 'B_N', 'B_A', 'B__', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT', 'B_P', 'B_V', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT', 'B_PRO', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_V', 'B_V', 'B_PONCT']
# token ['Un', 'voyage', 'étonnant', 'où', 'photos', ',', 'réalisations', ',', 'vieux', 'outils', ',', 'documents', 'anciens', ',', 'permettront', 'de', 'mesurer', 'combien', 'ce', 'petit', 'bout', 'de', 'terre', 'de', 'France', ',', 'situé', 'aux', 'à', 'les', 'Marches', 'de', "l'", 'Est', ',', 'lieu', 'de', 'passage', 'de', 'prédilection', 'des', 'de', 'les', 'invasions', ',', 'fut', 'une', 'terre', 'de', '<unk>', ',', 'et', 'combien', 'le', 'travail', 'de', 'ses', 'habitants', ',', '<unk>', 'à', 'la', 'tâche', ',', 'doit', 'être', 'reconnu', 'et', 'mis', 'en', 'valeur', '.']
# prediction ['B_D', 'B_N', 'B_A', 'B_PRO', 'B_N', 'B_PONCT', 'B_N', 'B_PONCT', 'B_A', 'B_N', 'B_PONCT', 'B_N', 'B_A', 'B_PONCT', 'B_V', 'B_P', 'B_V', 'B_ADV', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_PUNCT', 'B_VERB', 'B__', 'B_ADP', 'B_DET', 'B_PROPN', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PUNCT', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_PUNCT', 'B_CONJ', 'B_ADV', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_VERB', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_AUX', 'B_AUX', 'B_VERB', 'B_CONJ', 'B_VERB', 'B_ADP', 'B_NOUN', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_A', 'B_PRO', 'B_N', 'B_PONCT', 'B_N', 'B_PONCT', 'B_A', 'B_N', 'B_PONCT', 'B_N', 'B_A', 'B_PONCT', 'B_V', 'B_P', 'B_V', 'B_ADV', 'B_D', 'B_A', 'B_N', 'B_P', 'B_N', 'B_P', 'B_N', 'B_PONCT', 'B_V', 'B__', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_N', 'B_P', 'B_N', 'B_P', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_V', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT', 'B_C', 'B_ADV', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_A', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_V', 'B_V', 'B_V', 'B_C', 'B_V', 'B_P', 'B_N', 'B_PONCT']
# token ['Cette', 'exposition', ',', 'comme', 'devait', 'conclure', 'Roger', '<unk>', ',', '"', "n'", 'a', "d'", 'autre', 'ambition', 'que', "d'", 'apporter', 'un', 'modeste', 'témoignage', 'sur', 'le', 'passé', 'du', 'de', 'le', 'tissu', 'économique', 'de', 'la', 'région', '.']
# prediction ['B_DET', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_AUX', 'B_VERB', 'B_PROPN', 'B_PROPN', 'B_PUNCT', 'B_PUNCT', 'B_PART', 'B_VERB', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_ADV', 'B_ADP', 'B_VERB', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_PONCT', 'B_C', 'B_V', 'B_V', 'B_N', 'B_N', 'B_PONCT', 'B_PONCT', 'B_ADV', 'B_V', 'B_D', 'B_A', 'B_N', 'B_C', 'B_P', 'B_V', 'B_D', 'B_A', 'B_N', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_A', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['Elle', 'se', 'veut', 'aussi', 'message', "d'", 'espoir', 'en', "l'", 'avenir', '"', '.']
# prediction ['B_PRON', 'B_PRON', 'B_VERB', 'B_ADV', 'B_VERB', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_PUNCT']
# gold ['B_CL', 'B_CL', 'B_V', 'B_ADV', 'B_N', 'B_P', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_PONCT']
# token ['Ouverture', 'tous', 'les', 'jours', 'sauf', 'le', 'lundi', 'de', '14', 'h', '30', 'à', '18', 'h', '.']
# prediction ['B_ADV', 'B_DET', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NUM', 'B_NOUN', 'B_NUM', 'B_ADP', 'B_NUM', 'B_NOUN', 'B_PUNCT']
# gold ['B_N', 'B_A', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_A', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['Une', 'nouvelle', 'école', 'pour', 'la', 'commune']
# prediction ['B_DET', 'B_ADJ', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN']
# gold ['B_D', 'B_A', 'B_N', 'B_P', 'B_D', 'B_N']
# token ['Au', 'à', 'le', 'cours', 'de', 'la', 'cérémonie', "d'", 'inauguration', '.']
# prediction ['B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_PUNCT']
# gold ['B__', 'B_P', 'B_D', 'I_N', 'I_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT']
# token ['La', 'nouvelle', 'école', 'maternelle', 'a', 'été', 'inaugurée', 'en', 'présence', 'du', 'de', 'le', '<unk>', ',', 'du', 'de', 'le', 'président', 'du', 'de', 'le', 'conseil', 'général', ',', 'accompagné', 'de', 'MM.', '<unk>', 'et', '<unk>', ',', 'des', 'de', 'les', 'maires', 'et', 'représentants', 'de', 'la', 'communauté', 'de', 'communes', ',', 'de', "l'", 'inspecteur', "d'", 'académie', 'et', 'de', "l'", '<unk>', 'de', "l'", 'Education', 'nationale', 'de', 'la', 'circonscription', '.']
# prediction ['B_DET', 'B_ADJ', 'B_NOUN', 'B_ADJ', 'B_AUX', 'B_AUX', 'B_VERB', 'B_ADP', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PUNCT', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_PUNCT', 'B_VERB', 'B_ADP', 'B_PROPN', 'B_PROPN', 'B_CONJ', 'B_PROPN', 'B_PUNCT', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_CONJ', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_CONJ', 'B_ADP', 'B_DET', 'B_PROPN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_D', 'B_A', 'B_N', 'B_A', 'B_V', 'B_V', 'B_V', 'B_P', 'I_N', 'B__', 'I_P', 'B_D', 'B_N', 'B_PONCT', 'B__', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_A', 'B_PONCT', 'B_V', 'B_P', 'B_N', 'B_N', 'B_C', 'B_N', 'B_PONCT', 'B__', 'B_P', 'B_D', 'B_N', 'B_C', 'B_N', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_C', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_A', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['Après', 'avoir', 'coupé', 'le', 'ruban', 'qui', 'en', 'marque', 'symboliquement', "l'", 'entrée', ',', 'le', 'maire', 'et', 'la', 'directrice', 'ont', 'conduit', 'la', 'visite', '<unk>', 'des', 'de', 'les', 'locaux', '.']
# prediction ['B_ADP', 'B_AUX', 'B_VERB', 'B_DET', 'B_NOUN', 'B_PRON', 'B_PRON', 'B_VERB', 'B_VERB', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_DET', 'B_NOUN', 'B_CONJ', 'B_DET', 'B_NOUN', 'B_AUX', 'B_VERB', 'B_DET', 'B_NOUN', 'B_VERB', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_P', 'B_V', 'B_V', 'B_D', 'B_N', 'B_PRO', 'B_CL', 'B_V', 'B_ADV', 'B_D', 'B_N', 'B_PONCT', 'B_D', 'B_N', 'B_C', 'B_D', 'B_N', 'B_V', 'B_V', 'B_D', 'B_N', 'B_V', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['Dans', 'son', 'intervention', ',', 'M.', '<unk>', 'a', 'fait', "l'", 'historique', 'de', "l'", 'école', 'maternelle', ',', 'qui', 'existe', 'à', '<unk>', 'depuis', '1972', '.']
# prediction ['B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_NOUN', 'B_PROPN', 'B_AUX', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_PUNCT', 'B_PRON', 'B_VERB', 'B_ADP', 'B_PROPN', 'B_ADP', 'B_NUM', 'B_PUNCT']
# gold ['B_P', 'B_D', 'B_N', 'B_PONCT', 'B_N', 'B_N', 'B_V', 'B_V', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_A', 'B_PONCT', 'B_PRO', 'B_V', 'B_P', 'B_N', 'B_P', 'B_N', 'B_PONCT']
# token ['Elle', 'occupait', 'depuis', 'cette', 'date', ',', 'un', 'bâtiment', '<unk>', 'dans', 'le', 'parc', '<unk>', '.']
# prediction ['B_PRON', 'B_VERB', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_DET', 'B_NOUN', 'B_VERB', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PROPN', 'B_PUNCT']
# gold ['B_CL', 'B_V', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_D', 'B_N', 'B_V', 'B_P', 'B_D', 'B_N', 'B_N', 'B_PONCT']
# token ['En', '1996', ',', 'la', 'municipalité', 'étudie', 'la', 'possibilité', "d'", 'une', 'construction', '<unk>', '.']
# prediction ['B_ADP', 'B_NUM', 'B_PUNCT', 'B_DET', 'B_NOUN', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PROPN', 'B_PUNCT']
# gold ['B_P', 'B_N', 'B_PONCT', 'B_D', 'B_N', 'B_V', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_A', 'B_PONCT']
# token ['Une', 'réflexion', 'commune', 'est', 'menée', 'avec', 'les', 'enseignants', 'et', 'les', 'délégués', 'de', 'parents', "d'", 'élèves', ',', 'sous', 'la', 'conduite', 'du', 'de', 'le', '<unk>', '.']
# prediction ['B_DET', 'B_NOUN', 'B_ADJ', 'B_AUX', 'B_VERB', 'B_ADP', 'B_DET', 'B_NOUN', 'B_CONJ', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_A', 'B_V', 'B_V', 'B_P', 'B_D', 'B_N', 'B_C', 'B_D', 'B_N', 'B_P', 'B_N', 'B_P', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['Après', 'une', 'année', "d'", 'études', ',', 'la', 'conduite', 'des', 'de', 'les', 'travaux', 'est', 'menée', 'par', 'le', 'cabinet', 'Cadel', 'et', 'son', 'associé', ',', 'M.', '<unk>', ',', 'sous', 'le', 'contrôle', 'de', "l'", '<unk>', ',', 'en', 'neuf', 'mois', '.']
# prediction ['B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_PUNCT', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_AUX', 'B_VERB', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PROPN', 'B_CONJ', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_PROPN', 'B_PROPN', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PUNCT', 'B_ADP', 'B_NUM', 'B_NOUN', 'B_PUNCT']
# gold ['B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_V', 'B_V', 'B_P', 'B_D', 'B_N', 'B_N', 'B_C', 'B_D', 'B_N', 'B_PONCT', 'B_N', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['Le', 'coût', 'des', 'de', 'les', 'bâtiments', "s'", 'élève', 'à', '<unk>', 'F', ',', 'dont', '40', '%', 'de', 'subvention', 'de', "l'", 'Etat', ';', '20', '%', "d'", '<unk>', 'financement', 'et', '40', '%', "d'", 'emprunt', '.']
# prediction ['B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PRON', 'B_VERB', 'B_ADP', 'B_PROPN', 'B_N', 'B_PONCT', 'B_PRO', 'B_NUM', 'B_SYM', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PUNCT', 'B_NUM', 'B_SYM', 'B_ADP', 'B_PROPN', 'B_PROPN', 'B_CONJ', 'B_NUM', 'B_SYM', 'B_ADP', 'B_NOUN', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_CL', 'B_V', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_PRO', 'B_D', 'B_N', 'B_P', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_D', 'B_N', 'B_P', 'B_PREF', 'B_N', 'B_C', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT']
# token ['Le', 'mobilier', 'est', 'subventionné', 'à', '50', '%', 'par', 'le', 'conseil', 'général', '.']
# prediction ['B_DET', 'B_NOUN', 'B_VERB', 'B_ADJ', 'B_ADP', 'B_NUM', 'B_SYM', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_V', 'B_V', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_A', 'B_PONCT']
# token ['M.', '<unk>', 'a', 'adressé', 'ses', 'remerciements', 'aux', 'à', 'les', 'collectivités', '<unk>', ',', 'et', 'en', 'particulier', 'à', "l'", 'inspecteur', "d'", 'académie', ',', 'pour', 'la', 'création', ',', 'en', '1998', ',', "d'", 'une', 'cinquième', 'classe', 'et', 'la', 'nomination', 'de', 'deux', '<unk>', 'et', 'la', 'mise', 'à', 'disposition', 'à', 'la', 'rentrée', '1999', "d'", 'un', 'titulaire', 'mobile', '.']
# prediction ['B_NOUN', 'B_PROPN', 'B_V', 'B_V', 'B_D', 'B_N', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_VERB', 'B_PUNCT', 'B_CONJ', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_NUM', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_CONJ', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NUM', 'B_PROPN', 'B_CONJ', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_PUNCT']
# gold ['B_N', 'B_N', 'B_V', 'B_V', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_A', 'B_PONCT', 'B_C', 'B_P', 'I_A', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_P', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_A', 'B_N', 'B_C', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_C', 'B_D', 'B_N', 'B_P', 'B_N', 'B_P', 'B_D', 'B_N', 'B_N', 'B_P', 'B_D', 'B_N', 'B_A', 'B_PONCT']
# token ['M.', '<unk>', ',', 'président', 'du', 'de', 'le', 'conseil', 'général', ',', 'a', 'parlé', "d'", 'une', '"', 'réalisation', 'apte', 'à', "l'", 'épanouissement', 'des', 'de', 'les', 'petits', '"', ',', 'non', 'sans', 'rappeler', 'le', 'rôle', 'primordial', 'de', "l'", 'éducation', 'familiale', '.']
# prediction ['B_NOUN', 'B_PROPN', 'B_PUNCT', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_PUNCT', 'B_AUX', 'B_VERB', 'B_ADP', 'B_DET', 'B_PONCT', 'B_N', 'B_A', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_A', 'B_PONCT', 'B_PONCT', 'B_ADV', 'B_ADP', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_PUNCT']
# gold ['B_N', 'B_N', 'B_PONCT', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_A', 'B_PONCT', 'B_V', 'B_V', 'B_P', 'B_D', 'B_PONCT', 'B_N', 'B_A', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_PONCT', 'B_ADV', 'B_P', 'B_V', 'B_D', 'B_N', 'B_A', 'B_P', 'B_D', 'B_N', 'B_A', 'B_PONCT']
# token ["L'", 'inspecteur', "d'", 'académie', 'a', 'remercié', 'la', 'municipalité', "d'", 'avoir', 'mené', 'à', 'bien', 'son', 'projet', 'en', 'ayant', 'associé', 'les', 'différentes', 'parties', '<unk>', ':', 'enseignants', ',', 'parents', ',', 'pour', 'la', 'conception', 'des', 'de', 'les', 'locaux', 'et', 'la', 'qualité', 'des', 'de', 'les', 'matériaux', 'utilisés', '.']
# prediction ['B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_AUX', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADP', 'B_AUX', 'B_VERB', 'B_ADP', 'B_ADV', 'B_DET', 'B_NOUN', 'B_PRON', 'B_AUX', 'B_VERB', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_PROPN', 'B_PUNCT', 'B_NOUN', 'B_PUNCT', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_CONJ', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_VERB', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_P', 'B_N', 'B_V', 'B_V', 'B_D', 'B_N', 'B_P', 'B_V', 'B_V', 'I_P', 'I_ADV', 'B_D', 'B_N', 'B_P', 'B_V', 'B_V', 'B_D', 'B_A', 'B_N', 'B_A', 'B_PONCT', 'B_N', 'B_PONCT', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_C', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_V', 'B_PONCT']
# token ['Quant', 'au', 'à', 'le', '<unk>', ',', 'il', 'apprécie', "l'", 'énergie', '<unk>', 'pour', 'une', 'telle', 'réalisation', '.']
# prediction ['B_ADV', 'B__', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PUNCT', 'B_PRON', 'B_VERB', 'B_DET', 'B_NOUN', 'B_VERB', 'B_ADP', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_PUNCT']
# gold ['B_ADV', 'B__', 'I_P', 'B_D', 'B_N', 'B_PONCT', 'B_CL', 'B_V', 'B_D', 'B_N', 'B_V', 'B_P', 'B_D', 'B_A', 'B_N', 'B_PONCT']
# token ['Il', 'pense', 'que', "l'", 'espace', ',', 'les', 'couleurs', ',', 'le', 'silence', "d'", 'un', 'tel', 'lieu', 'ne', 'peuvent', "qu'", 'être', 'un', 'élément', "d'", 'harmonie', 'dans', 'la', 'vie', 'de', 'la', 'commune', ',', 'et', 'espère', 'que', "d'", 'autres', 'projets', 'seront', 'réalisés', 'dans', 'cet', 'esprit', '.']
# prediction ['B_PRON', 'B_VERB', 'B_SCONJ', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_PART', 'B_AUX', 'B_ADV', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_CONJ', 'B_VERB', 'B_SCONJ', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_AUX', 'B_VERB', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_CL', 'B_V', 'B_C', 'B_D', 'B_N', 'B_PONCT', 'B_D', 'B_N', 'B_PONCT', 'B_D', 'B_N', 'B_P', 'B_D', 'B_A', 'B_N', 'B_ADV', 'B_V', 'B_ADV', 'B_V', 'B_D', 'B_N', 'B_P', 'B_N', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_C', 'B_V', 'B_C', 'B_D', 'I_A', 'B_N', 'B_V', 'B_V', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['Les', 'enfants', 'et', 'les', 'pêcheurs']
# prediction ['B_D', 'B_N', 'B_C', 'B_D', 'B_N']
# gold ['B_D', 'B_N', 'B_C', 'B_D', 'B_N']
# token ['Ce', 'sont', 'finalement', 'les', 'élèves', 'de', 'la', 'classe', 'de', '<unk>', 'de', 'Jacky', '<unk>', 'qui', 'sont', 'venus', 'mettre', 'la', 'main', 'au', 'à', 'le', 'sac', 'poubelle', ',', 'dans', 'la', 'bonne', '<unk>', ',', 'comme', "s'", 'ils', 'étaient', 'là', 'pour', 'participer', 'à', 'un', 'jeu', 'de', '<unk>', ',', 'laissant', 'au', 'à', 'le', 'passage', 'le', 'soin', 'à', 'leurs', '<unk>', "d'", 'en', 'tirer', 'une', 'morale', '.']
# prediction ['B_PRON', 'B_VERB', 'B_ADV', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_ADP', 'B_NOUN', 'B_PROPN', 'B_PRON', 'B_AUX', 'B_VERB', 'B_VERB', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_ADJ', 'B_PROPN', 'B_PUNCT', 'B_SCONJ', 'B_PRON', 'B_PRON', 'B_VERB', 'B_ADV', 'B_ADP', 'B_VERB', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_PUNCT', 'B_VERB', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_PROPN', 'B_ADP', 'B_PRON', 'B_VERB', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_CL', 'B_V', 'B_ADV', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_P', 'B_N', 'B_N', 'B_PRO', 'B_V', 'B_V', 'B_V', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_A', 'B_N', 'B_PONCT', 'B_ADV', 'I_C', 'B_CL', 'B_V', 'B_ADV', 'B_P', 'B_V', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT', 'B_V', 'B__', 'B_P', 'B_D', 'B_N', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_P', 'B_CL', 'B_V', 'B_D', 'B_N', 'B_PONCT']
# token ['Une', 'seconde', 'opération', 'se', '<unk>', 'en', 'parallèle', 'sur', 'le', 'territoire', 'de', 'la', 'commune', ',', 'avec', 'un', 'groupe', "d'", 'une', 'dizaine', 'de', 'chevaliers', 'de', 'la', '<unk>', '"', 'La', '<unk>', '"', ',', 'des', 'pêcheurs', 'à', 'la', 'ligne', 'venus', 'nettoyer', 'les', 'rives', 'et', '<unk>', 'le', 'petit', 'ruisseau', 'qui', '<unk>', 'sous', 'les', '"', 'Sources', '"', 'avant', 'de', 'se', 'jeter', 'dans', "l'", '<unk>', '.']
# prediction ['B_DET', 'B_ADJ', 'B_NOUN', 'B_PRON', 'B_VERB', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PUNCT', 'B_DET', 'B_PROPN', 'B_PUNCT', 'B_PUNCT', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_AUX', 'B_VERB', 'B_DET', 'B_NOUN', 'B_CONJ', 'B_VERB', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_PRON', 'B_VERB', 'B_ADP', 'B_DET', 'B_PUNCT', 'B_NOUN', 'B_PUNCT', 'B_ADV', 'B_ADP', 'B_PRON', 'B_VERB', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PUNCT']
# gold ['B_D', 'B_A', 'B_N', 'B_CL', 'B_V', 'B_P', 'B_N', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_D', 'B_N', 'B_PONCT', 'B_PONCT', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_V', 'B_V', 'B_D', 'B_N', 'B_C', 'B_V', 'B_D', 'B_A', 'B_N', 'B_PRO', 'B_V', 'B_P', 'B_D', 'B_PONCT', 'B_N', 'B_PONCT', 'B_P', 'I_P', 'B_CL', 'B_V', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['Une', 'opération', 'destinée', 'aussi', 'à', 'faciliter', 'la', 'remontée', 'et', 'la', '<unk>', 'des', 'de', 'les', '<unk>', 'vers', 'la', 'rivière', '.']
# prediction ['B_DET', 'B_NOUN', 'B_VERB', 'B_ADV', 'B_ADP', 'B_VERB', 'B_DET', 'B_NOUN', 'B_CONJ', 'B_DET', 'B_PROPN', 'B__', 'B_ADP', 'B_DET', 'B_PROPN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_V', 'B_ADV', 'B_P', 'B_V', 'B_D', 'B_N', 'B_C', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['La', 'journée', 'de', 'nettoyage', 'de', "l'", 'environnement', 'placée', 'sous', 'la', 'bannière', 'du', 'de', 'le', '"', 'Printemps', 'de', "l'", 'environnement', '"', "n'", 'a', 'pas', 'connu', ',', 'à', '<unk>', ',', 'le', 'succès', 'que', 'la', 'municipalité', 'était', 'en', 'droit', "d'", 'attendre', '.']
# prediction ['B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_VERB', 'B_ADP', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_PUNCT', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_PART', 'B_AUX', 'B_ADV', 'B_VERB', 'B_PUNCT', 'B_ADP', 'B_PROPN', 'B_PUNCT', 'B_DET', 'B_NOUN', 'B_SCONJ', 'B_DET', 'B_NOUN', 'B_VERB', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_VERB', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_P', 'B_N', 'B_P', 'B_D', 'B_N', 'B_V', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_PONCT', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_ADV', 'B_V', 'B_ADV', 'B_V', 'B_PONCT', 'B_P', 'B_N', 'B_PONCT', 'B_D', 'B_N', 'B_PRO', 'B_D', 'B_N', 'B_V', 'B_P', 'B_N', 'B_P', 'B_V', 'B_PONCT']
# token ['Peut-être', 'a', '<unk>', 'eu', 'le', 'tort', ',', 'la', 'veille', ',', 'de', 'faire', 'installer', 'des', '<unk>', 'fixes', ',', 'synonymes', ',', 'à', '<unk>', ',', 'de', 'propreté', ',', 'ce', 'qui', 'a', 'eu', 'probablement', 'pour', 'effet', "d'", 'inciter', 'les', 'gens', 'à', 'rester', 'à', 'domicile', '.']
# prediction ['B_ADV', 'B_AUX', 'B_AUX', 'B_VERB', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_VERB', 'B_VERB', 'B_DET', 'B_PROPN', 'B_ADJ', 'B_PUNCT', 'B_X', 'B_PUNCT', 'B_ADP', 'B_PROPN', 'B_PUNCT', 'B_ADP', 'B_NOUN', 'B_PUNCT', 'B_PRON', 'B_PRON', 'B_AUX', 'B_VERB', 'B_ADV', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADP', 'B_VERB', 'B_ADP', 'B_NOUN', 'B_PUNCT']
# gold ['B_ADV', 'B_V', 'B_CL', 'B_V', 'B_D', 'B_N', 'B_PONCT', 'B_D', 'B_N', 'B_PONCT', 'B_P', 'B_V', 'B_V', 'B_D', 'B_N', 'B_A', 'B_PONCT', 'B_A', 'B_PONCT', 'B_P', 'I_ET', 'B_PONCT', 'B_P', 'B_N', 'B_PONCT', 'B_PRO', 'B_PRO', 'B_V', 'B_V', 'B_ADV', 'B_P', 'B_N', 'B_P', 'B_V', 'B_D', 'B_N', 'B_P', 'B_V', 'B_P', 'B_N', 'B_PONCT']
# token ['Les', 'enfants', '<unk>', 'saint', 'Honoré']
# prediction ['B_DET', 'B_NOUN', 'B_PROPN', 'B_PROPN', 'B_PROPN']
# gold ['B_D', 'B_N', 'B_V', 'B_N', 'B_N']
# token ['Les', 'petits', '<unk>', 'séduits', 'par', 'la', 'bonne', 'odeur', 'du', 'de', 'le', 'pain', '.']
# prediction ['B_DET', 'B_ADJ', 'B_PROPN', 'B_VERB', 'B_ADP', 'B_DET', 'B_ADJ', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_D', 'B_A', 'B_N', 'B_V', 'B_P', 'B_D', 'B_A', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['Depuis', 'quatre', 'ans', ',', 'les', 'boulangers', 'français', '<unk>', 'avec', 'leurs', 'clients', 'la', '<unk>', '.']
# prediction ['B_ADP', 'B_NUM', 'B_NOUN', 'B_PUNCT', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_VERB', 'B_ADP', 'B_DET', 'B_NOUN', 'B_DET', 'B_PROPN', 'B_PUNCT']
# gold ['B_P', 'B_D', 'B_N', 'B_PONCT', 'B_D', 'B_N', 'B_A', 'B_V', 'B_P', 'B_D', 'B_N', 'B_D', 'B_N', 'B_PONCT']
# token ['Ceux', "d'", '<unk>', 'ont', 'participé', 'à', "l'", 'événement', 'en', 'faisant', 'découvrir', 'leur', 'savoir-faire', 'et', 'leurs', 'recettes', '.']
# prediction ['B_PRON', 'B_ADP', 'B_PROPN', 'B_AUX', 'B_VERB', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_VERB', 'B_VERB', 'B_DET', 'B_NOUN', 'B_CONJ', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_PRO', 'B_P', 'B_N', 'B_V', 'B_V', 'B_P', 'B_D', 'B_N', 'B_P', 'B_V', 'B_V', 'B_D', 'B_N', 'B_C', 'B_D', 'B_N', 'B_PONCT']
# token ['Les', 'élèves', 'de', 'la', 'classe', 'de', '<unk>', 'de', "l'", 'école', 'Notre-Dame', 'ont', 'pris', 'part', 'aux', 'à', 'les', 'festivités', '.']
# prediction ['B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PROPN', 'B_AUX', 'B_VERB', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_P', 'B_D', 'B_N', 'B_N', 'B_V', 'B_V', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['Ils', 'ont', 'été', 'reçus', 'à', 'la', '<unk>', 'Leroy', 'pour', 'visiter', 'le', 'fournil', 'et', 'surtout', '<unk>', 'la', 'pâte', 'afin', 'de', 'confectionner', 'de', 'délicieux', 'pains', 'au', 'à', 'le', 'chocolat', "qu'", 'ils', 'ont', '<unk>', 'à', "l'", 'heure', 'du', 'de', 'le', 'goûter', 'avec', 'un', 'verre', 'de', 'jus', 'de', 'fruit', '.']
# prediction ['B_PRON', 'B_AUX', 'B_AUX', 'B_VERB', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PROPN', 'B_ADP', 'B_VERB', 'B_DET', 'B_NOUN', 'B_CONJ', 'B_ADV', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADV', 'B_ADP', 'B_NUM', 'B_ADP', 'B_PROPN', 'B_PROPN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_SCONJ', 'B_PRON', 'B_AUX', 'B_VERB', 'B_ADP', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_PUNCT']
# gold ['B_CL', 'B_V', 'B_V', 'B_V', 'B_P', 'B_D', 'B_N', 'B_N', 'B_P', 'B_V', 'B_D', 'B_N', 'B_C', 'B_ADV', 'B_V', 'B_D', 'B_N', 'B_P', 'I_P', 'B_V', 'B_D', 'B_A', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_PRO', 'B_CL', 'B_V', 'B_V', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_P', 'B_N', 'B_PONCT']
# token ['Quel', 'bonheur', "d'", 'entendre', 'la', '<unk>', '<unk>', "l'", 'histoire', 'de', 'saint', 'Honoré', ',', 'ce', 'jeune', 'homme', '<unk>', 'annonçant', 'à', 'sa', 'vieille', '<unk>', "qu'", 'il', 'voulait', 'se', 'faire', 'prêtre', '!']
# prediction ['B_DET', 'B_NOUN', 'B_ADP', 'B_VERB', 'B_DET', 'B_PROPN', 'B_PROPN', 'B_DET', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_PROPN', 'B_PUNCT', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_AUX', 'B_VERB', 'B_ADP', 'B_DET', 'B_ADJ', 'B_AUX', 'B_C', 'B_CL', 'B_V', 'B_CL', 'B_V', 'B_ADV', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_P', 'B_V', 'B_D', 'B_N', 'B_V', 'B_D', 'B_N', 'B_P', 'B_N', 'B_N', 'B_PONCT', 'B_D', 'B_A', 'B_N', 'B_A', 'B_V', 'B_P', 'B_D', 'B_A', 'B_N', 'B_C', 'B_CL', 'B_V', 'B_CL', 'B_V', 'B_N', 'B_PONCT']
# token ['Quel', 'bonheur', 'aussi', "d'", 'entrer', 'dans', "l'", '<unk>', 'de', 'la', '<unk>', 'et', 'de', 'découvrir', 'les', 'secrets', 'du', 'de', 'le', '<unk>', 'du', 'de', 'le', 'pain', '!']
# prediction ['B_DET', 'B_NOUN', 'B_ADV', 'B_ADP', 'B_VERB', 'B_ADP', 'B_DET', 'B_PROPN', 'B_ADP', 'B_DET', 'B_PROPN', 'B_CONJ', 'B_ADP', 'B_VERB', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_PROPN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_ADV', 'B_P', 'B_V', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_C', 'B_P', 'B_V', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['Bref', ',', 'en', 'quittant', 'le', 'fournil', ',', 'chacun', 'ne', '<unk>', 'que', 'de', 'remettre', 'la', 'main', 'à', 'la', 'pâte', 'avec', '<unk>', 'et', 'Daniel', '.']
# prediction ['B_INTJ', 'B_PUNCT', 'B_PRON', 'B_VERB', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_PRON', 'B_PART', 'B_VERB', 'B_SCONJ', 'B_ADP', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_CONJ', 'B_PROPN', 'B_PUNCT']
# gold ['B_ADV', 'B_PONCT', 'B_P', 'B_V', 'B_D', 'B_N', 'B_PONCT', 'B_PRO', 'B_ADV', 'B_V', 'B_ADV', 'B_P', 'B_V', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_C', 'B_N', 'B_PONCT']
# token ["L'", 'agenda', 'sportif']
# prediction ['B_D', 'B_N', 'B_A']
# gold ['B_D', 'B_N', 'B_A']
# token ['Football']
# prediction ['B_N']
# gold ['B_N']
# token ['Une', 'seule', 'rencontre', 'est', 'au', 'à', 'le', 'programme', 'des', 'de', 'les', 'licenciés', 'du', 'de', 'le', 'FC', "aujourd'", 'hui', '.']
# prediction ['B_DET', 'B_ADJ', 'B_NOUN', 'B_VERB', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B__', 'B_P', 'B_D', 'B_A', 'B_P', 'I_N', 'B_PONCT']
# gold ['B_D', 'B_A', 'B_N', 'B_V', 'B__', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_P', 'I_N', 'B_PONCT']
# token ["L'", 'équipe', 'B', ',', 'chez', 'les', '<unk>', ',', '<unk>', 'à', 'partir', 'de', '15', 'h', ',', 'sur', 'la', '<unk>', 'du', 'de', 'le', 'terrain', "d'", 'honneur', ',', 'face', 'à', 'la', 'formation', 'de', '<unk>', '.']
# prediction ['B_DET', 'B_NOUN', 'B_PROPN', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PUNCT', 'B_VERB', 'B_ADP', 'B_VERB', 'B_ADP', 'B_NUM', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_PROPN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_PUNCT', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_V', 'B_P', 'I_V', 'I_P', 'B_D', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT', 'B_N', 'I_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT']
# token ['Une', 'journée', 'du', 'de', 'le', 'championnat', 'de', 'promotion', 'de', 'première', 'division', 'départementale', '.']
# prediction ['B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_ADJ', 'B_NOUN', 'B_ADJ', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_P', 'B_A', 'B_N', 'B_A', 'B_PONCT']
# token ['<unk>']
# prediction ['B_AUX']
# gold ['B_N']
# token ['Les', 'cyclistes', 'et', '<unk>', 'peuvent', 'se', 'réunir', 'ce', 'matin', ',', 'à', '9', 'h', ',', 'place', '<unk>', ',', 'à', "l'", 'occasion', "d'", 'une', 'sortie', "d'", 'entraînement', '.']
# prediction ['B_DET', 'B_NOUN', 'B_CONJ', 'B_AUX', 'B_AUX', 'B_PRON', 'B_VERB', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_NUM', 'B_NOUN', 'B_PUNCT', 'B_NOUN', 'B_PROPN', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_C', 'B_N', 'B_V', 'B_CL', 'B_V', 'B_D', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_N', 'B_N', 'B_PONCT', 'B_P', 'I_D', 'I_N', 'I_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT']
# token ['Cet', 'entraînement', 'sera', 'renouvelé', 'demain', ',', 'aux', 'à', 'les', 'mêmes', 'horaires', '.']
# prediction ['B_DET', 'B_NOUN', 'B_AUX', 'B_VERB', 'B_NOUN', 'B_PUNCT', 'B__', 'B_ADP', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_V', 'B_V', 'B_ADV', 'B_PONCT', 'B__', 'B_P', 'B_D', 'B_A', 'B_N', 'B_PONCT']
# token ['<unk>']
# prediction ['B_AUX']
# gold ['B_N']
# token ['Les', 'membres', 'du', 'de', 'le', 'club', 'auront', "l'", 'occasion', 'de', "s'", 'entraîner', 'cet', 'après-midi', ',', 'dès', '14', 'h', ',', 'salle', '<unk>', '.']
# prediction ['B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADP', 'B_PRON', 'B_VERB', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_NUM', 'B_NOUN', 'B_PUNCT', 'B_NOUN', 'B_PROPN', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_V', 'B_D', 'B_N', 'B_P', 'B_CL', 'B_V', 'B_D', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_N', 'B_N', 'B_PONCT']
# token ['<unk>']
# prediction ['B_AUX']
# gold ['B_N']
# token ['Les', 'tireurs', 'de', 'la', '<unk>', 'ont', 'rendez-vous', 'à', 'partir', 'de', '9', 'h', ',', 'sur', 'les', 'pas', 'de', 'tir', ',', 'à', "l'", 'occasion', "d'", 'une', 'séance', "d'", 'entraînement', '.']
# prediction ['B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_PROPN', 'B_AUX', 'B_VERB', 'B_ADP', 'B_VERB', 'B_ADP', 'B_NUM', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_V', 'B_N', 'B_P', 'I_V', 'I_P', 'B_D', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT', 'B_P', 'I_D', 'I_N', 'I_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT']
# token ['<unk>']
# prediction ['B_AUX']
# gold ['B_N']
# token ['Une', 'sortie', '<unk>', "d'", 'entraînement', 'est', 'organisée', "aujourd'", 'hui', ',', 'à', 'partir', 'de', '9', 'h', ',', 'pour', 'les', '<unk>', 'du', 'de', 'le', 'club', '.']
# prediction ['B_DET', 'B_NOUN', 'B_VERB', 'B_ADP', 'B_NOUN', 'B_AUX', 'B_VERB', 'B_ADP', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_VERB', 'B_ADP', 'B_NUM', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_PROPN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_A', 'B_P', 'B_N', 'B_V', 'B_V', 'B_P', 'I_N', 'B_PONCT', 'B_P', 'I_V', 'I_P', 'B_D', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['<unk>', 'au', 'à', 'le', 'local', 'du', 'de', 'le', 'club', '.']
# prediction ['B_V', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['<unk>', 'de', 'Guy', '<unk>']
# prediction ['B_PROPN', 'B_ADP', 'B_PROPN', 'B_PROPN']
# gold ['B_N', 'B_P', 'B_N', 'B_N']
# token ['M.', '<unk>', 'avait', '44', 'ans', '.']
# prediction ['B_NOUN', 'B_PROPN', 'B_AUX', 'B_NUM', 'B_NOUN', 'B_PUNCT']
# gold ['B_N', 'B_N', 'B_V', 'B_D', 'B_N', 'B_PONCT']
# token ['Nous', '<unk>', 'avec', 'beaucoup', 'de', 'tristesse', ',', 'le', 'décès', 'de', 'Guy', '<unk>', ',', 'suite', 'à', 'une', 'longue', 'et', '<unk>', 'maladie', ',', 'à', "l'", 'âge', 'de', '44', 'ans', '.']
# prediction ['B_CL', 'B_V', 'B_P', 'B_ADV', 'B_ADP', 'B_NOUN', 'B_PUNCT', 'B_DET', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_PROPN', 'B_PUNCT', 'B_NOUN', 'B_ADP', 'B_DET', 'B_ADJ', 'B_CONJ', 'B_AUX', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NUM', 'B_NOUN', 'B_PUNCT']
# gold ['B_CL', 'B_V', 'B_P', 'B_ADV', 'B_P', 'B_N', 'B_PONCT', 'B_D', 'B_N', 'B_P', 'B_N', 'B_N', 'B_PONCT', 'B_N', 'I_P', 'B_D', 'B_A', 'B_C', 'B_A', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['Né', 'à', '<unk>', 'le', '11', 'février', '1955', ',', 'Guy', 'était', 'arrivé', 'tout', 'jeune', 'avec', 'sa', 'famille', 'à', '<unk>', '.']
# prediction ['B_VERB', 'B_ADP', 'B_PROPN', 'B_DET', 'B_NUM', 'B_NOUN', 'B_NUM', 'B_PUNCT', 'B_PROPN', 'B_AUX', 'B_VERB', 'B_DET', 'B_ADJ', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_PUNCT']
# gold ['B_V', 'B_P', 'B_N', 'B_D', 'B_A', 'B_N', 'B_N', 'B_PONCT', 'B_N', 'B_V', 'B_V', 'B_ADV', 'B_A', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT']
# token ['Il', 'avait', 'épousé', '<unk>', '<unk>', 'le', '26', 'octobre', '1974', 'et', 'de', 'leur', 'union', ',', 'sont', 'nés', 'une', 'fille', 'et', 'deux', 'garçons', ',', 'âgés', 'respectivement', 'de', '24', ',', '23', 'et', '14', 'ans', '.']
# prediction ['B_PRON', 'B_AUX', 'B_VERB', 'B_AUX', 'B_VERB', 'B_DET', 'B_NUM', 'B_NOUN', 'B_NUM', 'B_CONJ', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_AUX', 'B_VERB', 'B_DET', 'B_NOUN', 'B_CONJ', 'B_NUM', 'B_NOUN', 'B_PUNCT', 'B_ADJ', 'B_ADV', 'B_ADP', 'B_NUM', 'B_PUNCT', 'B_NUM', 'B_CONJ', 'B_NUM', 'B_NOUN', 'B_PUNCT']
# gold ['B_CL', 'B_V', 'B_V', 'B_N', 'B_N', 'B_D', 'B_A', 'B_N', 'B_N', 'B_C', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_V', 'B_V', 'B_D', 'B_N', 'B_C', 'B_D', 'B_N', 'B_PONCT', 'B_A', 'B_ADV', 'B_P', 'B_D', 'B_PONCT', 'B_D', 'B_C', 'B_D', 'B_N', 'B_PONCT']
# token ['Guy', 'a', 'consacré', 'toute', 'sa', 'vie', 'professionnelle', 'à', 'la', 'laiterie', '<unk>', 'à', '<unk>', ',', 'au', 'à', 'le', 'poste', 'de', 'chef', '<unk>', 'où', 'il', 'comptait', 'de', 'nombreux', 'amis', '.']
# prediction ['B_PROPN', 'B_AUX', 'B_VERB', 'B_DET', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PROPN', 'B_ADP', 'B_PROPN', 'B_PUNCT', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_AUX', 'B_PRON', 'B_PRON', 'B_VERB', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_PUNCT']
# gold ['B_N', 'B_V', 'B_V', 'B_A', 'B_D', 'B_N', 'B_A', 'B_P', 'B_D', 'B_N', 'B_N', 'B_P', 'B_N', 'B_PONCT', 'B__', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_N', 'B_PRO', 'B_CL', 'B_V', 'B_D', 'B_A', 'B_N', 'B_PONCT']
# token ['Guy', '<unk>', 'était', 'une', 'personne', 'très', 'connue', 'dans', 'la', 'commune', 'et', 'aux', 'à', 'les', 'alentours', ',', 'pour', 'son', 'grand', '<unk>', 'aux', 'à', 'les', 'autres', 'et', 'sa', 'participation', 'à', 'la', 'vie', 'associative', 'du', 'de', 'le', 'village', ';']
# prediction ['B_PROPN', 'B_PROPN', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADV', 'B_VERB', 'B_ADP', 'B_DET', 'B_NOUN', 'B_CONJ', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_ADJ', 'B_PROPN', 'B__', 'B_ADP', 'B_DET', 'B_ADJ', 'B_CONJ', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADJ', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_N', 'B_N', 'B_V', 'B_D', 'B_N', 'B_ADV', 'B_V', 'B_P', 'B_D', 'B_N', 'B_C', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_P', 'B_D', 'B_A', 'B_N', 'B__', 'B_P', 'B_D', 'B_PRO', 'B_C', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_A', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['il', 'a', 'assuré', 'la', 'présidence', 'de', 'la', 'société', 'de', 'pêche', '"', 'La', 'Gaule', '<unk>', '"', 'durant', 'une', 'dizaine', "d'", 'années', '.']
# ...
# gold ['B_CL', 'B_ADV', 'B_V', 'B_CL', 'B_V', 'B_PRO', 'B_PRO', 'B_CL', 'B_V', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['Cela', ',', 'nous', 'devons', 'le', 'faire', 'dans', 'un', 'débat', 'de', 'politique', 'extérieure', '.']
# prediction ['B_PRO', 'B_PONCT', 'B_CL', 'B_V', 'B_CL', 'B_V', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_A', 'B_PONCT']
# gold ['B_PRO', 'B_PONCT', 'B_CL', 'B_V', 'B_CL', 'B_V', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_A', 'B_PONCT']
# token ['Nous', 'sommes', 'ici', 'pour', 'discuter', 'de', "l'", 'actualité', '<unk>', ',', 'laquelle', 'consiste', 'à', 'traiter', 'pour', 'la', 'deuxième', 'fois', "d'", 'une', 'résolution', 'sur', 'le', 'thème', 'des', 'de', 'les', '"', 'prisonniers', '<unk>', 'albanais', 'en', 'Serbie', '"', '.']
# prediction ['B_CL', 'B_V', 'B_ADV', 'B_ADP', 'B_VERB', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PROPN', 'B_PUNCT', 'B_PRON', 'B_VERB', 'B_ADP', 'B_VERB', 'B_ADP', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_PUNCT', 'B_NOUN', 'B_VERB', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_PUNCT', 'B_PUNCT']
# gold ['B_CL', 'B_V', 'B_ADV', 'B_P', 'B_V', 'B_P', 'B_D', 'B_N', 'B_A', 'B_PONCT', 'B_PRO', 'B_V', 'B_P', 'B_V', 'B_P', 'B_D', 'B_A', 'B_N', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_PONCT', 'B_N', 'B_A', 'B_A', 'B_P', 'B_N', 'B_PONCT', 'B_PONCT']
# token ['Je', 'me', 'demande', 'vraiment', 'pourquoi', 'nous', 'avons', 'pris', 'cette', 'résolution', 'en', 'septembre', 'dernier', '.']
# prediction ['B_CL', 'B_CL', 'B_V', 'B_ADV', 'I_ADV', 'B_CL', 'B_V', 'B_V', 'B_D', 'B_N', 'B_P', 'B_N', 'B_A', 'B_PONCT']
# gold ['B_CL', 'B_CL', 'B_V', 'B_ADV', 'B_ADV', 'B_CL', 'B_V', 'B_V', 'B_D', 'B_N', 'B_P', 'B_N', 'B_A', 'B_PONCT']
# token ['Je', "n'", 'ai', 'pas', 'encore', 'lu', 'ni', 'entendu', 'que', 'le', 'Conseil', "s'", 'y', 'soit', 'intéressé', '.']
# prediction ['B_PRON', 'B_PART', 'B_AUX', 'B_ADV', 'B_ADV', 'B_ADJ', 'B_CONJ', 'B_VERB', 'B_SCONJ', 'B_DET', 'B_NOUN', 'B_PRON', 'B_ADV', 'B_AUX', 'B_VERB', 'B_PUNCT']
# gold ['B_CL', 'B_ADV', 'B_V', 'B_ADV', 'I_ADV', 'B_V', 'B_C', 'B_V', 'B_C', 'B_D', 'B_N', 'B_CL', 'B_CL', 'B_V', 'B_V', 'B_PONCT']
# token ['Je', 'me', 'demande', 'vraiment', 'si', 'le', 'Conseil', 'possède', 'encore', 'un', 'minimum', "d'", 'humanité', '!']
# prediction ['B_PRON', 'B_PRON', 'B_VERB', 'B_ADV', 'B_SCONJ', 'B_DET', 'B_NOUN', 'B_VERB', 'B_ADV', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_PUNCT']
# gold ['B_CL', 'B_CL', 'B_V', 'B_ADV', 'B_C', 'B_D', 'B_N', 'B_V', 'B_ADV', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT']
# token ['Si', 'les', 'représentants', 'du', 'de', 'le', 'Conseil', 'avaient', 'un', 'fils', ',', 'un', 'frère', 'ou', 'un', 'père', 'dans', 'les', 'prisons', 'serbes', ',', 'ils', '<unk>', 'plus', 'vite', ',', 'croyez', '-moi', '!']
# prediction ['B_SCONJ', 'B_DET', 'B_NOUN', 'B__', 'B_P', 'B_D', 'B_N', 'B_V', 'B_D', 'B_N', 'B_PONCT', 'B_D', 'B_N', 'B_C', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_A', 'B_PONCT', 'B_CL', 'B_V', 'B_ADV', 'B_ADV', 'B_PUNCT', 'B_VERB', 'B_PRON', 'B_PUNCT']
# gold ['B_C', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_V', 'B_D', 'B_N', 'B_PONCT', 'B_D', 'B_N', 'B_C', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_A', 'B_PONCT', 'B_CL', 'B_V', 'B_ADV', 'B_ADV', 'B_PONCT', 'B_V', 'B_PRO', 'B_PONCT']
# token ['Comme', 'vous', 'tous', ',', "j'", 'entends', 'les', 'appels', 'à', "l'", 'aide', 'des', 'de', 'les', 'mères', ',', 'des', 'de', 'les', 'épouses', 'et', 'des', 'de', 'les', 'soeurs', 'des', 'de', 'les', '<unk>', 'albanais', 'qui', '<unk>', 'dans', 'les', '<unk>', 'serbes', '.']
# prediction ['B_SCONJ', 'B_PRON', 'B_PRON', 'B_PUNCT', 'B_PRON', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B__', 'B_P', 'B_D', 'B_N', 'B_C', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PROPN', 'B_PRON', 'B_VERB', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PROPN', 'B_PUNCT']
# gold ['B_P', 'B_PRO', 'B_A', 'B_PONCT', 'B_CL', 'B_V', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B__', 'B_P', 'B_D', 'B_N', 'B_C', 'B__', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_A', 'B_PRO', 'B_V', 'B_P', 'B_D', 'B_N', 'B_A', 'B_PONCT']
# token ['Je', 'dois', 'toutefois', 'être', 'honnête', 'et', 'dire', 'que', 'personne', 'ne', 'les', 'aide', '.']
# prediction ['B_CL', 'B_V', 'B_ADV', 'B_VERB', 'B_ADJ', 'B_CONJ', 'B_VERB', 'B_SCONJ', 'B_NOUN', 'B_PART', 'B_D', 'B_N', 'B_PONCT']
# gold ['B_CL', 'B_V', 'B_ADV', 'B_V', 'B_A', 'B_C', 'B_V', 'B_C', 'B_PRO', 'B_ADV', 'B_CL', 'B_V', 'B_PONCT']
# token ['Je', 'me', 'suis', 'rendu', 'dernièrement', 'à', '<unk>', 'et', ',', 'à', "l'", 'université', ',', "j'", 'ai', 'cherché', 'en', 'vain', 'trois', 'étudiants', 'que', 'je', 'connais', 'depuis', 'de', 'longues', 'années', '.']
# prediction ['B_PRON', 'B_PRON', 'B_AUX', 'B_VERB', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_CONJ', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_PRON', 'B_AUX', 'B_VERB', 'B_ADP', 'B_ADJ', 'B_NUM', 'B_NOUN', 'B_PRON', 'B_PRON', 'B_VERB', 'B_ADP', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_PUNCT']
# gold ['B_CL', 'B_CL', 'B_V', 'B_V', 'B_ADV', 'B_P', 'B_N', 'B_C', 'B_PONCT', 'B_P', 'B_D', 'B_N', 'B_PONCT', 'B_CL', 'B_V', 'B_V', 'B_P', 'I_A', 'B_D', 'B_N', 'B_PRO', 'B_CL', 'B_V', 'B_P', 'B_D', 'B_A', 'B_N', 'B_PONCT']
# token ['Je', 'sais', 'où', 'ils', 'sont', ':', 'dans', 'une', 'prison', 'serbe', ',', 'sans', 'aucune', 'raison', '!']
# prediction ['B_PRON', 'B_VERB', 'B_PRON', 'B_PRON', 'B_VERB', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_PUNCT', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_CL', 'B_V', 'B_ADV', 'B_CL', 'B_V', 'B_PONCT', 'B_P', 'B_D', 'B_N', 'B_A', 'B_PONCT', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# 100%|█████████████████████████████████████████████| 4/4 [00:04<00:00,  1.12s/it]
# token ['Il', "n'", 'y', 'a', 'aucun', 'motif', 'pour', "qu'", 'ils', 'y', 'soient', '.']
# prediction ['B_PRON', 'B_PART', 'B_CL', 'B_V', 'B_D', 'B_N', 'B_P', 'I_C', 'B_CL', 'B_ADV', 'B_VERB', 'B_PUNCT']
# gold ['B_CL', 'B_ADV', 'B_CL', 'B_V', 'B_D', 'B_N', 'B_P', 'I_C', 'B_CL', 'B_CL', 'B_V', 'B_PONCT']
# token ['Ils', "n'", 'ont', 'été', 'impliqués', 'dans', 'aucune', 'action', 'terroriste', 'ou', 'militaire', '.']
# prediction ['B_PRON', 'B_PART', 'B_AUX', 'B_AUX', 'B_VERB', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADJ', 'B_CONJ', 'B_ADJ', 'B_PUNCT']
# gold ['B_CL', 'B_ADV', 'B_V', 'B_V', 'B_V', 'B_P', 'B_D', 'B_N', 'B_A', 'B_C', 'B_A', 'B_PONCT']
# token ['Je', 'crois', 'que', 'nous', 'devrions', 'nous', 'pencher', 'sur', 'ce', 'problème', '.']
# prediction ['B_CL', 'B_V', 'B_C', 'B_CL', 'B_V', 'B_CL', 'B_V', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# gold ['B_CL', 'B_V', 'B_C', 'B_CL', 'B_V', 'B_CL', 'B_V', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['<unk>', '<unk>', ',', 'la', 'docteur', '<unk>', 'condamnée', 'le', '13', 'janvier', 'à', '<unk>', ',', 'est', 'maintenant', 'gravement', 'malade', 'et', 'mise', 'sous', 'surveillance', 'dans', 'une', 'clinique', 'de', 'la', 'même', 'ville', '.']
# prediction ['B_PROPN', 'B_PROPN', 'B_PUNCT', 'B_DET', 'B_NOUN', 'B_PROPN', 'B_VERB', 'B_DET', 'B_NUM', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_PUNCT', 'B_VERB', 'B_ADV', 'B_ADV', 'B_ADJ', 'B_CONJ', 'B_VERB', 'B_ADP', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_PUNCT']
# gold ['B_N', 'B_N', 'B_PONCT', 'B_D', 'B_N', 'B_A', 'B_V', 'B_D', 'B_A', 'B_N', 'B_P', 'B_N', 'B_PONCT', 'B_V', 'B_ADV', 'B_ADV', 'B_A', 'B_C', 'B_V', 'B_P', 'B_N', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_A', 'B_N', 'B_PONCT']
# token ['Elle', 'a', 'été', 'condamnée', 'parce', "qu'", 'en', 'tant', 'que', 'médecin', ',', 'elle', 'a', 'porté', 'secours', 'à', 'des', 'blessés', 'des', 'de', 'les', 'deux', 'camps', '.']
# prediction ['B_PRON', 'B_AUX', 'B_AUX', 'B_VERB', 'B_ADV', 'B_SCONJ', 'B_ADP', 'B_ADV', 'B_SCONJ', 'B_NOUN', 'B_PUNCT', 'B_PRON', 'B_AUX', 'B_VERB', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_NUM', 'B_NOUN', 'B_PUNCT']
# gold ['B_CL', 'B_V', 'B_V', 'B_V', 'B_C', 'I_C', 'B_P', 'I_ADV', 'I_C', 'B_N', 'B_PONCT', 'B_CL', 'B_V', 'B_V', 'B_N', 'B_P', 'B_D', 'B_N', 'B__', 'B_P', 'B_D', 'B_A', 'B_N', 'B_PONCT']
# token ['Ce', "n'", 'est', 'ni', 'une', 'terroriste', ',', 'ni', 'même', 'une', 'activiste', 'de', "l'", '<unk>', '!']
# prediction ['B_PRON', 'B_PART', 'B_VERB', 'B_CONJ', 'B_DET', 'B_NOUN', 'B_PUNCT', 'B_CONJ', 'B_ADV', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PUNCT']
# gold ['B_CL', 'B_ADV', 'B_V', 'B_C', 'B_D', 'B_N', 'B_PONCT', 'B_C', 'B_ADV', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['Personne', "n'", 'aide', 'cette', 'femme', 'à', 'sortir', 'de', 'prison', '.']
# prediction ['B_PRON', 'B_PART', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADP', 'B_VERB', 'B_ADP', 'B_NOUN', 'B_PUNCT']
# gold ['B_PRO', 'B_ADV', 'B_V', 'B_D', 'B_N', 'B_P', 'B_V', 'B_P', 'B_N', 'B_PONCT']
# token ['Je', 'crois', 'également', 'que', 'le', 'Conseil', 'de', 'ministres', 'ne', "s'", 'intéresse', 'pas', 'le', 'moins', 'du', 'de', 'le', 'monde', 'à', 'ces', '<unk>', '.']
# prediction ['B_CL', 'B_V', 'B_ADV', 'B_SCONJ', 'B_DET', 'B_NOUN', 'B_ADP', 'B_NOUN', 'B_PART', 'B_PRON', 'B_VERB', 'B_ADV', 'B_DET', 'B_ADV', 'B__', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PUNCT']
# gold ['B_CL', 'B_V', 'B_ADV', 'B_C', 'B_D', 'B_N', 'B_P', 'B_N', 'B_ADV', 'B_CL', 'B_V', 'B_ADV', 'B_D', 'B_ADV', 'B__', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['Je', 'trouve', 'cela', 'dramatique', '.']
# prediction ['B_PRON', 'B_VERB', 'B_PRON', 'B_ADJ', 'B_PUNCT']
# gold ['B_CL', 'B_V', 'B_PRO', 'B_A', 'B_PONCT']
# token ['Nous', '<unk>', 'les', 'appels', 'à', "l'", 'aide', 'et', 'aucun', 'de', 'nos', 'responsables', 'ne', 'les', 'entend', '.']
# prediction ['B_PRON', 'B_VERB', 'B_DET', 'B_NOUN', 'B_ADP', 'B_DET', 'B_NOUN', 'B_CONJ', 'B_PRON', 'B_ADP', 'B_DET', 'B_NOUN', 'B_PART', 'B_PRON', 'B_VERB', 'B_PUNCT']
# gold ['B_CL', 'B_V', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_C', 'B_PRO', 'B_P', 'B_D', 'B_N', 'B_ADV', 'B_CL', 'B_V', 'B_PONCT']
# token ["C'", 'est', 'grave', '.']
# prediction ['B_PRON', 'B_VERB', 'B_ADJ', 'B_PUNCT']
# gold ['B_CL', 'B_V', 'B_A', 'B_PONCT']
# token ['Les', 'sanctions', 'se', '<unk>', 'petit', 'à', 'petit', '.']
# prediction ['B_DET', 'B_NOUN', 'B_PRON', 'B_AUX', 'B_ADV', 'B_ADP', 'B_ADJ', 'B_PUNCT']
# gold ['B_D', 'B_N', 'B_CL', 'B_V', 'B_A', 'I_P', 'I_A', 'B_PONCT']
# token ['A', '<unk>', 'jamais', '<unk>', 'à', 'ne', '<unk>', 'ces', 'sanctions', 'que', 'quand', 'le', 'gouvernement', 'serbe', 'aura', 'vraiment', 'fait', 'un', 'geste', '?']
# prediction ['B_ADP', 'B_PROPN', 'B_ADV', 'B_V', 'B_P', 'B_ADV', 'B_V', 'B_D', 'B_N', 'B_C', 'B_C', 'B_D', 'B_N', 'B_A', 'B_V', 'B_ADV', 'B_VERB', 'B_DET', 'B_NOUN', 'B_PUNCT']
# gold ['B_V', 'B_CL', 'B_ADV', 'B_V', 'B_P', 'B_ADV', 'B_V', 'B_D', 'B_N', 'B_ADV', 'B_C', 'B_D', 'B_N', 'B_A', 'B_V', 'B_ADV', 'B_V', 'B_D', 'B_N', 'B_PONCT']
# token ['Je', 'ne', 'pense', 'pas', '...']
# prediction ['B_PRON', 'B_PART', 'B_VERB', 'B_ADV', 'B_PUNCT']
# gold ['B_CL', 'B_ADV', 'B_V', 'B_ADV', 'B_PONCT']
# token ['Nous', 'devrions', 'nous', 'inquiéter', 'également', 'de', 'la', 'situation', 'à', '<unk>', '.']
# prediction ['B_PRON', 'B_AUX', 'B_PRON', 'B_VERB', 'B_ADV', 'B_ADP', 'B_DET', 'B_NOUN', 'B_ADP', 'B_PROPN', 'B_PUNCT']
# gold ['B_CL', 'B_V', 'B_CL', 'B_V', 'B_ADV', 'B_P', 'B_D', 'B_N', 'B_P', 'B_N', 'B_PONCT']
# token ['Je', 'suis', 'ici', 'entièrement', "d'", 'accord', 'avec', 'M.', 'Sakellariou', '.']
# prediction ['B_PRON', 'B_VERB', 'B_ADV', 'B_ADV', 'B_P', 'B_N', 'B_P', 'B_N', 'B_N', 'B_PONCT']
# gold ['B_CL', 'B_V', 'B_ADV', 'B_ADV', 'B_P', 'I_N', 'B_P', 'B_N', 'B_N', 'B_PONCT']
# token ['Nous', 'ne', 'pouvons', 'pas', 'seulement', 'exiger', 'que', 'les', 'Serbes', 'se', 'comportent', 'correctement', ',', 'nous', 'devons', 'également', 'obliger', 'ceux', 'à', 'qui', 'nous', 'sommes', 'venus', 'en', 'aide', 'à', 'ne', 'pas', 'répondre', 'à', 'la', 'violence', 'par', 'la', 'violence', '.']
# prediction ['B_PRON', 'B_PART', 'B_AUX', 'B_ADV', 'B_ADV', 'B_V', 'B_C', 'B_D', 'B_N', 'B_CL', 'B_V', 'B_ADV', 'B_PONCT', 'B_CL', 'B_V', 'B_ADV', 'B_V', 'B_PRO', 'B_P', 'B_PRO', 'B_CL', 'B_V', 'B_V', 'B_P', 'B_N', 'B_P', 'B_PART', 'B_ADV', 'B_V', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# gold ['B_CL', 'B_ADV', 'B_V', 'B_ADV', 'B_ADV', 'B_V', 'B_C', 'B_D', 'B_N', 'B_CL', 'B_V', 'B_ADV', 'B_PONCT', 'B_CL', 'B_V', 'B_ADV', 'B_V', 'B_PRO', 'B_P', 'B_PRO', 'B_CL', 'B_V', 'B_V', 'B_P', 'B_N', 'B_P', 'B_ADV', 'I_ADV', 'B_V', 'B_P', 'B_D', 'B_N', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['Dans', 'le', 'cas', 'contraire', ',', 'nous', "n'", 'aurons', 'plus', 'la', 'moindre', 'crédibilité', '.']
# prediction ['B_P', 'B_D', 'B_N', 'B_A', 'B_PONCT', 'B_CL', 'B_ADV', 'B_V', 'B_ADV', 'B_DET', 'B_ADJ', 'B_NOUN', 'B_PUNCT']
# gold ['B_P', 'B_D', 'B_N', 'B_A', 'B_PONCT', 'B_CL', 'B_ADV', 'B_V', 'B_ADV', 'B_D', 'B_A', 'B_N', 'B_PONCT']
# token ["C'", 'est', 'pourquoi', 'je', 'crois', 'également', 'que', 'nous', 'devons', 'exiger', 'que', 'ceux', 'que', 'nous', 'avons', '<unk>', 'se', 'comportent', 'réellement', ',', 'eux', 'aussi', ',', 'correctement', '.']
# prediction ['B_CL', 'I_V', 'I_ADV', 'B_CL', 'B_V', 'B_ADV', 'B_SCONJ', 'B_PRON', 'B_AUX', 'B_VERB', 'B_SCONJ', 'B_PRON', 'B_SCONJ', 'B_PRON', 'B_AUX', 'B_AUX', 'B_PRON', 'B_VERB', 'B_ADV', 'B_PUNCT', 'B_PRON', 'B_ADV', 'B_PUNCT', 'B_ADV', 'B_PUNCT']
# gold ['B_CL', 'I_V', 'I_ADV', 'B_CL', 'B_V', 'B_ADV', 'B_C', 'B_CL', 'B_V', 'B_V', 'B_C', 'B_PRO', 'B_PRO', 'B_CL', 'B_V', 'B_V', 'B_CL', 'B_V', 'B_ADV', 'B_PONCT', 'B_PRO', 'B_ADV', 'B_PONCT', 'B_ADV', 'B_PONCT']
# token ['<unk>', 'ne', 'peut', 'être', 'divisée', '!']
# prediction ['B_AUX', 'B_PART', 'B_AUX', 'B_VERB', 'B_ADJ', 'B_PUNCT']
# gold ['B_N', 'B_ADV', 'B_V', 'B_V', 'B_V', 'B_PONCT']
# token ['Nous', 'avons', 'connu', 'suffisamment', 'de', 'villes', '<unk>', 'en', 'Europe', 'et', 'nous', 'en', 'connaissons', 'encore', '.']
# prediction ['B_PRON', 'B_AUX', 'B_VERB', 'B_ADV', 'B_ADP', 'B_NOUN', 'B_VERB', 'B_ADP', 'B_PROPN', 'B_CONJ', 'B_PRON', 'B_PRON', 'B_VERB', 'B_ADV', 'B_PUNCT']
# gold ['B_CL', 'B_V', 'B_V', 'B_ADV', 'B_P', 'B_N', 'B_V', 'B_P', 'B_N', 'B_C', 'B_CL', 'B_CL', 'B_V', 'B_ADV', 'B_PONCT']
# token ['Je', 'pense', 'que', 'nous', 'devons', 'empêcher', 'cela', '.']
# prediction ['B_CL', 'B_V', 'B_C', 'B_CL', 'B_V', 'B_V', 'B_PRO', 'B_PONCT']
# gold ['B_CL', 'B_V', 'B_C', 'B_CL', 'B_V', 'B_V', 'B_PRO', 'B_PONCT']
# token ['Si', 'la', 'KFOR', 'est', 'attaquée', ',', 'je', 'ne', 'puis', 'que', 'dire', 'que', 'ce', 'sont', 'nos', 'fils', 'et', 'que', 'nous', 'les', 'avons', 'envoyés', 'pour', 'aider', 'les', 'Albanais', 'et', 'les', 'Serbes', ',', 'et', 'qui', 'que', 'ce', 'soit', "d'", 'autre', 'qui', 'vit', 'au', 'à', 'le', 'Kosovo', '.']
# prediction ['B_SCONJ', 'B_DET', 'B_PROPN', 'B_VERB', 'B_ADJ', 'B_PUNCT', 'B_PRON', 'B_PART', 'B_ADV', 'B_SCONJ', 'B_VERB', 'B_SCONJ', 'B_PRON', 'B_VERB', 'B_DET', 'B_NOUN', 'B_CONJ', 'B_SCONJ', 'B_PRON', 'B_PRON', 'B_AUX', 'B_VERB', 'B_ADP', 'B_V', 'B_D', 'B_N', 'B_C', 'B_D', 'B_N', 'B_PONCT', 'B_C', 'B_PRO', 'B_SCONJ', 'B_PRON', 'B_VERB', 'B_ADP', 'B_PRON', 'B_PRON', 'B_VERB', 'B__', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PUNCT']
# gold ['B_C', 'B_D', 'B_N', 'B_V', 'B_V', 'B_PONCT', 'B_CL', 'B_ADV', 'B_V', 'B_ADV', 'B_V', 'B_C', 'B_CL', 'B_V', 'B_D', 'B_N', 'B_C', 'B_C', 'B_CL', 'B_CL', 'B_V', 'B_V', 'B_P', 'B_V', 'B_D', 'B_N', 'B_C', 'B_D', 'B_N', 'B_PONCT', 'B_C', 'B_PRO', 'I_C', 'I_CL', 'I_V', 'B_P', 'B_PRO', 'B_PRO', 'B_V', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# token ['Nous', 'estimons', "qu'", 'ils', 'ne', 'peuvent', 'être', 'punis', 'parce', "qu'", 'ils', 'viennent', 'volontairement', 'en', 'aide', 'au', 'à', 'le', 'Kosovo', '.']
# prediction ['B_CL', 'B_V', 'B_C', 'B_CL', 'B_ADV', 'B_AUX', 'B_AUX', 'B_VERB', 'B_ADV', 'B_SCONJ', 'B_PRON', 'B_VERB', 'B_ADV', 'B_ADP', 'B_NOUN', 'B__', 'B_ADP', 'B_DET', 'B_PROPN', 'B_PUNCT']
# gold ['B_CL', 'B_V', 'B_C', 'B_CL', 'B_ADV', 'B_V', 'B_V', 'B_V', 'B_C', 'I_C', 'B_CL', 'B_V', 'B_ADV', 'B_P', 'B_N', 'B__', 'B_P', 'B_D', 'B_N', 'B_PONCT']
# torch.Size([167, 122])

# %%
TP
# Out:
# tensor([0.0000e+00, 1.6430e+03, 0.0000e+00, 1.4342e+05, 2.0000e+01, 0.0000e+00,
#         0.0000e+00, 5.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 8.1000e+01,
#         3.5000e+01, 3.0000e+00, 0.0000e+00, 0.0000e+00, 7.8000e+01, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00])
